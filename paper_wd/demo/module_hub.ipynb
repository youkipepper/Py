# %%
import torch
model = torch.hub.load('pytorch/vision:v0.6.0', 'deeplabv3_resnet101', pretrained=True)
model.eval() # 设置为评估模式
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.6.0" to /Users/youkipepper/.cache/torch/hub/v0.6.0.zip
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /Users/youkipepper/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100%|██████████| 170M/170M [00:23<00:00, 7.63MB/s]
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /Users/youkipepper/.cache/torch/hub/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
# 100%|██████████| 233M/233M [00:32<00:00, 7.59MB/s]
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
# ...

# %%
torch.hub.list('pytorch/vision:v0.6.0') # 列出所有模型
# Out:
# Using cache found in /Users/youkipepper/.cache/torch/hub/pytorch_vision_v0.6.0
# ['alexnet',
#  'deeplabv3_resnet101',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'fcn_resnet101',
#  'googlenet',
#  'inception_v3',
#  'mobilenet_v2',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext50_32x4d',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'wide_resnet101_2',
#  'wide_resnet50_2']
